# %%
################################################################
############# Revision of basic commands in R ##################
################################################################

#Vector is an object in R
#c() is used for generating vectors
#c stands for combine (combine values to make a vector)
#diffrerent types of vectors could be generated in R
#For example
x=c(5,6,9,10)#A numerical vector with 4 observations or elements
#All obs must be of same type (numeric, character, or logical)
y=c("Ram", "Shyam", "Sam", "Thomas")#A character vector with 4 observations or elements

# %%
#These vectors can be combined to make dataframe
z=data.frame(x,y)
z
# Out:
#   x  y
# 1  5 Ram
# 2  6 Shyam
# 3  9 Sam
# 4 10 Thomas

# %%
str(z)#See the structure of dataframe
class(z)#What kind of object it is
is.data.frame(z)#Verify
# Out:
# 'data.frame':	4 obs. of  2 variables:
#  $ x: num  5 6 9 10
#  $ y: Factor w/ 4 levels "Ram","Sam","Shyam",..: 1 3 2 4
# [1] "data.frame"
# [1] TRUE

# %%
dim(z)#Rows, columns
names(z) #Shows column names
nrow(z) #Number of rows
ncol(z) #Number of columns
# Out:
# [1] 4 2
# [1] "x" "y"
# [1] 4
# [1] 2

# %%
#The columns of dataframe can be accessed by name using $ sign
z$x
#Assignment of a column to some other variable
a=z$y
# Out:
# [1]  5  6  9 10

# %%
# Import csv/xls/xlsx file
#Import Lung Cap_Random_csv file from Import dataset tab
#Import RELIANCE_Bhavcopy_xlsx file from Import dataset tab
library(xlsx)

# %%
#How to work on data
#See the first 6 entries using head command
x=read.xlsx(file="../Data/RELIANCE_Bhavcopy_xlsx.xlsx", sheetName = "Sheet 1") #Assign Reliance to x
head(x)
head(x,10)
# Out:
#   Symbol   Series Open   High   Low    Close  LTP    Trdqty  Value
# 1 RELIANCE EQ     696.80 709.75 687.15 706.55 707.10 4299217 3003173233
# 2 RELIANCE EQ     712.25 726.90 710.35 724.65 723.55 4683491 3369419363
# 3 RELIANCE EQ     727.40 730.95 713.35 716.15 714.80 4238367 3057754094
# 4 RELIANCE EQ     715.00 724.95 694.10 699.50 702.00 6619586 4696715963
# 5 RELIANCE EQ     697.05 724.00 696.65 717.55 718.15 4703147 3341832553
# 6 RELIANCE EQ     716.70 718.90 713.30 714.75 714.45  460231  329647099
#   Number_trades Date
# 1 107910        20120102
# 2 116827        20120103
# 3 103487        20120104
# 4 153163        20120105
# 5 132079        20120106
# 6  11413        20120107
#    Symbol   Series Open   High   Low    Close  LTP    Trdqty  Value
# 1  RELIANCE EQ     696.80 709.75 687.15 706.55 707.10 4299217 3003173233
# 2  RELIANCE EQ     712.25 726.90 710.35 724.65 723.55 4683491 3369419363
# 3  RELIANCE EQ     727.40 730.95 713.35 716.15 714.80 4238367 3057754094
# 4  RELIANCE EQ     715.00 724.95 694.10 699.50 702.00 6619586 4696715963
# 5  RELIANCE EQ     697.05 724.00 696.65 717.55 718.15 4703147 3341832553
# 6  RELIANCE EQ     716.70 718.90 713.30 714.75 714.45  460231  329647099
# 7  RELIANCE EQ     714.45 714.45 702.45 706.25 707.00 4202878 2973990327
# 8  RELIANCE EQ     712.00 739.00 712.00 736.20 734.35 4507724 3277927434
# 9  RELIANCE EQ     737.90 753.00 731.50 748.25 747.85 4842143 3598638051
# 10 RELIANCE EQ     747.50 752.95 732.60 736.90 740.00 3251624 2412343827
#    Number_trades Date
# 1  107910        20120102
# 2  116827        20120103
# 3  103487        20120104
# 4  153163        20120105
# 5  132079        20120106
# 6   11413        20120107
# 7  110805        20120109
# 8   99465        20120110
# 9  112553        20120111
# 10  88335        20120112

# %%
#See the last 6 entries using tail command
tail(x)
tail(x,10)
# Out:
#     Symbol   Series Open   High   Low    Close  LTP    Trdqty  Value
# 740 RELIANCE EQ     902.35 904.15 891.80 893.75 894.00 2419143 2170327613
# 741 RELIANCE EQ     893.75 897.15 880.00 884.15 886.00 5138493 4556983279
# 742 RELIANCE EQ     886.60 892.65 880.10 888.85 889.70 1117804  989726637
# 743 RELIANCE EQ     888.50 899.05 886.95 897.00 897.50 1584461 1418244675
# 744 RELIANCE EQ     897.10 898.40 877.10 880.15 882.20 2657831 2344774965
# 745 RELIANCE EQ     880.00 893.90 879.05 891.15 892.05 1934955 1718774956
#     Number_trades Date
# 740 79030         20141223
# 741 46204         20141224
# 742 23646         20141226
# 743 32127         20141229
# 744 52295         20141230
# 745 43317         20141231
#     Symbol   Series Open   High   Low    Close  LTP    Trdqty  Value
# 736 RELIANCE EQ     865.25 874.90 864.45 869.50 871.60 4749947 4132820407
# 737 RELIANCE EQ     881.55 884.80 864.65 880.10 880.25 3422050 2999770666
# 738 RELIANCE EQ     885.10 908.40 882.50 900.55 900.45 4588473 4126518156
# 739 RELIANCE EQ     902.00 906.80 891.00 904.90 904.75 1898416 1705977398
# 740 RELIANCE EQ     902.35 904.15 891.80 893.75 894.00 2419143 2170327613
# 741 RELIANCE EQ     893.75 897.15 880.00 884.15 886.00 5138493 4556983279
# 742 RELIANCE EQ     886.60 892.65 880.10 888.85 889.70 1117804  989726637
# 743 RELIANCE EQ     888.50 899.05 886.95 897.00 897.50 1584461 1418244675
# 744 RELIANCE EQ     897.10 898.40 877.10 880.15 882.20 2657831 2344774965
# 745 RELIANCE EQ     880.00 893.90 879.05 891.15 892.05 1934955 1718774956
#     Number_trades Date
# 736 110568        20141217
# 737  77641        20141218
# 738 107582        20141219
# 739  53810        20141222
# 740  79030        20141223
# 741  46204        20141224
# 742  23646        20141226
# 743  32127        20141229
# 744  52295        20141230
# 745  43317        20141231

# %%
#Extract i,j value
x[1,3] #Element in First row and third column

#Extract first row
x[1,]

#Extract second column
x[,2]
# Out:
# [1] 696.8
#   Symbol   Series Open  High   Low    Close  LTP   Trdqty  Value
# 1 RELIANCE EQ     696.8 709.75 687.15 706.55 707.1 4299217 3003173233
#   Number_trades Date
# 1 107910        20120102
#   [1] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
#  [26] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
#  [51] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
#  [76] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [101] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [126] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [151] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [176] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [201] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [226] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [251] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [276] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [301] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [326] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [351] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [376] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [401] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [426] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [451] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [476] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [501] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [526] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [551] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [576] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [601] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [626] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [651] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [676] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [701] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# [726] EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ EQ
# Levels: EQ

# %%
#Basic Statistical functions in R Studio
#Compute mean for the variable Traded quantity in the file
mean(x$Trdqty)
# Out:
# [1] 3322285

# %%
#Compute median
median(x$Trdqty)
# Out:
# [1] 2992305

# %%
#Compute minimum value
min(x$Trdqty)
# Out:
# [1] 111054

# %%
#Compute maximum value
max(x$Trdqty)
# Out:
# [1] 12665322

# %%
#Compute range
range(x$Trdqty)
# Out:
# [1]   111054 12665322

# %%
#Compute standard deviation
sd(x$Trdqty)
# Out:
# [1] 1523236

# %%
#Compute variance
var(x$Trdqty)
# Out:
# [1] 2.320247e+12

# %%
#Compute covariance
cov(x$Trdqty, x$Number_trades)
# Out:
# [1] 41047982334

# %%
#Compute correlation
cor(x$Trdqty, x$Number_trades)
# Out:
# [1] 0.7729134

# %%
#Compute descriptive summary
summary(x$Trdqty)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#   111054  2302432  2992305  3322285  3953604 12665322

# %%
###################################################
################ Linear Regression ################
###################################################
library(datasets)
data("women")#Import inbuilt dataset "women
women
# Out:
#    height weight
# 1  58     115
# 2  59     117
# 3  60     120
# 4  61     123
# 5  62     126
# 6  63     129
# 7  64     132
# 8  65     135
# 9  66     139
# 10 67     142
# 11 68     146
# 12 69     150
# 13 70     154
# 14 71     159
# 15 72     164

# %%
help(women) #To see what is there in the file

# %%
##Bivariate Regression
attach(women) #So that columns of women file can be read directly
plot(height, weight)
cor(weight,height)
# Out:
# The following objects are masked from women (pos = 3):
#
#     height, weight
# [1] 0.9954948
# plot without title

# %%
#Do Regression
lm(weight~height)
Model1=lm(weight~height)#Assign model
#Write Equation
abline(Model1)#Add trend line
# Out:
# Call:
# lm(formula = weight ~ height)
#
# Coefficients:
# (Intercept)       height
#      -87.52         3.45
# Error in int_abline(a = a, b = b, h = h, v = v, untf = untf, ...): plot.new has not been called yet
# Traceback:
#
# 1. abline(Model1)
# 2. int_abline(a = a, b = b, h = h, v = v, untf = untf, ...)

# %%
#Compute fitted values
Model1$fitted.values
Model1$residuals
Model1$coefficients
Model1$fitted.values
Model1$coefficients

# %%
#Compute residuals
Model1$residuals

# %%
#See the desired outputs (coefficients and p-values)
#First, see the output
model_summary=summary(Model1)
names(model_summary)

# %%
#Now extract
model_summary$call #The Model
model_summary$residuals
model_summary$coefficients
model_summary$coefficients[1,1] #Extract element
model_summary$df
model_summary$r.squared
model_summary$adj.r.squared#Adjusted R-square
model_summary$fstatistic[1]
pf(model_summary$fstatistic[1],model_summary$fstatistic[2],model_summary$fstatistic[3],lower.tail=FALSE)#p-value of F-statistics

# %%
#Predict based on known values
#Syntax(model name, name of the dependent variable in data.frame)
predict(Model1, data.frame(height=60))
#119.4833 (-87.516+3.45*60)

# %%
#Predict for more than one value
predict(Model1, data.frame(height=c(60,70,80)))
(-87.516+3.45*60)
(-87.516+3.45*70)
(-87.516+3.45*80)

# %%
###################################################
#Diagnostics on residuals
###################################################
#Assumption of normality
x=resid(model_summary)

# %%
#Check mean and median
mean(x)
median(x)
#A huge difference exist, Hence not normal

# %%
hist(x)
boxplot(x)
shapiro.test(x) #Shapiro-Wilk normality test

# %%
#Null hypothesis: Data is normal
#Works when we have large number of datasets

#Jarque-Bera test
require(normtest)
jb.norm.test(x)

# %%
#Check by random numbers those are normal
set.seed(1)
y=rnorm(1000)
jb.norm.test(y)

# %%
#Null hypothesis: Data is normal
#joint hypothesis of the skewness being zero and the excess kurtosis being zero

#######################################################

# %%
#Homoscedasticity (The variance of residuals is constant)
plot(height, weight)
abline(Model1)

# %%
#The errors are constant around the regression line
###################################


#New example for mulple linear regression
###################################
data("airquality")#Import inbuilt dataset of "airquality"
airquality
help(airquality)
#See the characteristics of data by plotting
attach(airquality)
plot(airquality)

# %%
#Run the regression, a general model of all possible variables
lm(Ozone~Solar.R+Wind+Temp+Month+Day)
#Assign to an object
model_2=lm(Ozone~Solar.R+Wind+Temp+Month+Day)
summary(model_2)

# %%
#Run new model removing the effect of Days
model_3=lm(Ozone~Solar.R+Wind+Temp+Month)
summary(model_3)

# %%
###################################################
#Diagnostics on residuals
###################################################
#Assumption of normality
x=resid(model_3)

# %%
#Check mean and median
mean(x)
median(x)

# %%
#A huge difference exist, Hence not normal

hist(x)
boxplot(x)
shapiro.test(x) #Shapiro-Wilk normality test
#Null hypothesis: Data is normal
#Works when we have large number of datasets

# %%
#Jarque-Bera test
require(normtest)
jb.norm.test(x)
#Null hypothesis: Data is normal
#joint hypothesis of the skewness being zero and the excess kurtosis being zero
#######################################################
